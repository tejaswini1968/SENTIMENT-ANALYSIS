# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswini1968/SENTIMENT-ANALYSIS/blob/main/project_sentiment_analysis_single_function_support_vector_machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT - SENTIMENT ANALYSIS ON AMAZON PRODUCT REVIEWS USING MACHINE LEARNING ALGORITHMS

# %% [markdown]
# # sample size 50,919 - positve,negative are 23030 each,neutral 4859

# %% [markdown]
# ### Importing Necessary Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading the Amazon Reviews data into jupyter notebook using pandas library

# %%
df1 = pd.read_csv('Amazon_Unlocked_Mobile-csv.csv')
df1.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %% [markdown]
# ### Renaming the column names with underscore character

# %%
df1.rename(columns={'Product Name':'Product_Name','Brand Name':'Brand_Name','Review Votes':'Review_Votes'},inplace=True)
df1.head()
# Out:
#                                         Product_Name Brand_Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review_Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %% [markdown]
# ### Slicing the data based on number of Review votes greater than or equal to 2 - out of total 4,13,840 samples , 66,171 selected

# %%
df2 = df1.loc[df1.Review_Votes >= 2]
df2.shape
# Out:
# (66171, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66171 entries, 12 to 413803
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_Name  66171 non-null  object
#  1   Brand_Name    54811 non-null  object
#  2   Price         65099 non-null  float64
#  3   Rating        66171 non-null  int64
#  4   Reviews       66125 non-null  object
#  5   Review_Votes  66171 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.5+ MB

# %% [markdown]
# ### Dropping the unnecessary columns

# %%
df2.drop(columns=(['Product_Name','Brand_Name','Price','Review_Votes']),inplace=True)
df2.head()
# Out:
# C:\Users\Siva_Guddanti\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     Rating                                            Reviews
# 12       5  These guys are the best! I had a little situat...
# 16       5  I was able to get the phone I previously owned...
# 22       1  I purchased this phone in December as a christ...
# 68       4  First off, let me say I've been a Nokia user s...
# 69       5  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...

# %%
df2.shape
# Out:
# (66171, 2)

# %% [markdown]
# ### Finding the NaN (null) values if any

# %%
df2.isnull().sum()
# Out:
# Rating      0
# Reviews    46
# dtype: int64

# %% [markdown]
# ### Dropping the NaN values

# %%
df2.dropna(inplace=True)
df2.shape
# Out:
# C:\Users\Siva_Guddanti\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# (66125, 2)

# %% [markdown]
# ### verifying that all the NaN values are dropped

# %%
df2.isnull().sum()
# Out:
# Rating     0
# Reviews    0
# dtype: int64

# %% [markdown]
# ### finding the unique values in the Reviews column

# %%
np.unique(df2.Reviews)
# Out:
# array(["!!!!!Update!!!!! a year later and this phone has some serious problems......the battery life is non-existent I took it off the charger this morning with 100% battery life two hours later it's down to 10% battery life I can power the phone down for about 3 minutes and power it back up and the battery life goes up to about 30% and then 15 minutes after that it's dead. The phone randomly reboots itself several times a day. a couple of days ago I took the back off the phone and all the screws holding the phone together just popped out.. Very poorly put together. the phone seriously lags at times, I've performed a factory reset (that deletes everything) to help improve the speed of the phone but it still runs slow. the camera still works but only if I don't use the Flash. if I use the flash the phone with power off. it was an okay phone when I first brought it, but if you're looking for something long-term this is not the phone. the problems that I wrote about above, probably started happening 6 to 7 months after purchase phone not worth paying $120 bucks for I'm giving it one star...... Had a little problem with loading picture text... Went in and change some setting and problem solved.The only problem I have is it will NOT hold a GPS signal. I mean going around the corner the phone will loose the gps signal. I almost got lost going to atl but thank goodness my wife had her phone. I am starting to notice that the power button is getting stuck.... over all a ok phone if your not relying on gps",
#        '"Condition: Used - Like NewComments: BRAND NEW - the only thing that is used is the battery, which is still in good condition......."My decision to buy the above item was based on the above description from the seller. In my analysis, I should have asked myself in which phone the battery was used if the phone itself was not used, but trusted the seller for it. However, if the phone came with 115 contacts\' numbers on it, besides text messages and various call logs, then I am at a loss as to what the seller\'s BRAND NEW description meant. Was it my mind that was playing games on me, or it was the seller?This is utter dishonesty, mischievous, totally unacceptable, against all business ethics, and need to be condemned in no uncertain terms.\'DISHONESTY\' ON THE PART OF ONE OR THE OTHER IS THE ATTITUDE THAT HAS BROUGHT THE WORLD TO WHERE WE ARE TODAY - TOTAL CHAOS, INSTABILITY, WAR, DISORDER, BEING AT EACH OTHERS THROAT. ETC. ETC.Personally I believe it is best to always tell the truth -TRUTH ALWAYS PREVAILS - and have one\'s peace, rather than telling lies and sitting on thorns. To this seller, my advice is not to go by this route again, for the next victim may not be as kind, sympathetic, and considerate as I am, and may want to demand his/her pound of flesh.Sorry if I appear to be too hard on you, madam.',
#        '"I WILL NEVER ORDER ANOTHER PHONE FROM AMAZON AGAIN!!! IT\'S SOLD AS A SPRINT PHONE, THE PHONE IS BRAND NEW AND SPRINT CAN NOT ACTIVATED THE PHONE!!! HOW DO YOU SELL A PHONE WITH AN INVALID EN NUMBER?? REALLY!?!?"',
#        ..., '👍',
#        '👍👌👍👌👍 Great Phone my first iPhone and I love it has fast internet and no cracks I just love it👌😘',
#        '👍👍'], dtype=object)

# %%
df2.head()
# Out:
#     Rating                                            Reviews
# 12       5  These guys are the best! I had a little situat...
# 16       5  I was able to get the phone I previously owned...
# 22       1  I purchased this phone in December as a christ...
# 68       4  First off, let me say I've been a Nokia user s...
# 69       5  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...

# %% [markdown]
# ### Resetting the index in the dataframe

# %%
df2.reset_index(drop=True,inplace=True)
df2.head()
# Out:
#    Rating                                            Reviews
# 0       5  These guys are the best! I had a little situat...
# 1       5  I was able to get the phone I previously owned...
# 2       1  I purchased this phone in December as a christ...
# 3       4  First off, let me say I've been a Nokia user s...
# 4       5  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...

# %% [markdown]
# ### Original ratings are on the scale of 1,2,3,4,5. We can see the number of each category ratings.

# %%
sns.countplot(df2.Rating)
# Out:
# C:\Users\Siva_Guddanti\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
df2.head(1)
# Out:
#    Rating                                            Reviews
# 0       5  These guys are the best! I had a little situat...

# %% [markdown]
# ### Project deliverables - positive(2),neutral(1),negative(0) - we have reclassify the ratings of 1 to 5 scale into 0,1,2 categories- 1,2 ratings are negative(0), 3 rating is neutral(1), 4,5 ratings are positive(2)

# %%
def custom_encoder(df):
    df.replace(to_replace=1,value=0,inplace=True)
    df.replace(to_replace=2,value=0,inplace=True)
    df.replace(to_replace=3,value=1,inplace=True)
    df.replace(to_replace=4,value=2,inplace=True)
    df.replace(to_replace=5,value=2,inplace=True)

# %% [markdown]
# ### Calling the function to re-classify the Ratings column

# %%
custom_encoder(df2.Rating)
# Out:
# C:\Users\Siva_Guddanti\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df2.head()
# Out:
#    Rating                                            Reviews
# 0       2  These guys are the best! I had a little situat...
# 1       2  I was able to get the phone I previously owned...
# 2       0  I purchased this phone in December as a christ...
# 3       2  First off, let me say I've been a Nokia user s...
# 4       2  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...

# %%
Amazon_data=df2

# %%
Amazon_data.head()
# Out:
#    Rating                                            Reviews
# 0       2  These guys are the best! I had a little situat...
# 1       2  I was able to get the phone I previously owned...
# 2       0  I purchased this phone in December as a christ...
# 3       2  First off, let me say I've been a Nokia user s...
# 4       2  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...

# %% [markdown]
# ### Data is not balanced - positve reviews are 38,236, negative reviews are 23,030, neutral reviews are 4,859

# %%
sns.countplot(Amazon_data.Rating)
# Out:
# C:\Users\Siva_Guddanti\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
Amazon_data.Rating.value_counts()
# Out:
# 2    38236
# 0    23030
# 1     4859
# Name: Rating, dtype: int64

# %%
Amazon_data_positive = Amazon_data.loc[Amazon_data.Rating == 2]

# %%
Amazon_data_positive.head()
# Out:
#    Rating                                            Reviews
# 0       2  These guys are the best! I had a little situat...
# 1       2  I was able to get the phone I previously owned...
# 3       2  First off, let me say I've been a Nokia user s...
# 4       2  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...
# 5       2  This is a solidly-built unlocked phone that is...

# %%
Amazon_data_positive.shape
# Out:
# (38236, 2)

# %% [markdown]
# ### Balancing the number of positive and negative reviews with equal 23,030 reviews

# %%
Amazon_data_positive = Amazon_data_positive[0:23030]
Amazon_data_positive.shape
# Out:
# (23030, 2)

# %%
Amazon_data_neg = Amazon_data.loc[Amazon_data.Rating == 0]
Amazon_data_neg.shape
# Out:
# (23030, 2)

# %%
Amazon_data_neu = Amazon_data.loc[Amazon_data.Rating == 1]
Amazon_data_neu.shape
# Out:
# (4859, 2)

# %% [markdown]
# ### Concatinating the three Series objects into single dataframe

# %%
Amazon_data_final = pd.concat([Amazon_data_positive,Amazon_data_neg,Amazon_data_neu],axis=0)

# %% [markdown]
# ### Final sample size = 50,919 - after some data wrangling

# %%
Amazon_data_final.shape
# Out:
# (50919, 2)

# %%
sns.countplot(Amazon_data_final.Rating)
# Out:
# C:\Users\Siva_Guddanti\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
Amazon_data_final.Rating.value_counts()
# Out:
# 2    23030
# 0    23030
# 1     4859
# Name: Rating, dtype: int64

# %%
Amazon_data_final.head()
# Out:
#    Rating                                            Reviews
# 0       2  These guys are the best! I had a little situat...
# 1       2  I was able to get the phone I previously owned...
# 3       2  First off, let me say I've been a Nokia user s...
# 4       2  Nokia Asha 302 Unlocked GSM Phone with 3.2MP C...
# 5       2  This is a solidly-built unlocked phone that is...

# %% [markdown]
# ### Resetting the index in the dataframe

# %%
Amazon_data_final.reset_index(drop=True,inplace=True)
Amazon_data_final.index
# Out:
# RangeIndex(start=0, stop=50919, step=1)

# %%
Amazon_data_final.tail()
# Out:
#        Rating                                            Reviews
# 50914       1  Cost of cell phone was a steal! Like new. Howe...
# 50915       1  This is a great phone for people who like flip...
# 50916       1  Phone was for my brother. It gets the job done...
# 50917       1  It seemed to be working well, but my dad has h...
# 50918       1  I like flip phones, they are easily to use.I h...

# %% [markdown]
# ### Shuffling the data randomly and resetting the index

# %%
Amazon_data_final = Amazon_data_final.sample(frac=1).reset_index(drop=True)

# %%
Amazon_data_final.head(100)
# Out:
#     Rating                                            Reviews
# 0        2  It's great for the money just takes time to ge...
# 1        0  The worst ... SCREW LOOSE, Water entered DAMAG...
# 2        2  This Item is allot of fun, but don't go out an...
# 3        0  Buy this phone for gifting it to a family and ...
# 4        0  When I got the phone it was in perfect conditi...
# ..     ...                                                ...
# 95       1  HTC one X is good phone. Earlier i bought it f...
# 96       0  Phone was network locked and did not meet my e...
# 97       1  The product is great however it doesn't worked...
# 98       1  Quite finicky with GSM retailers - 4G/LTE phas...
# 99       2                                        Great phone
#
# [100 rows x 2 columns]

# %%
Amazon_data_final.shape
# Out:
# (50919, 2)

# %%
Amazon_data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50919 entries, 0 to 50918
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rating   50919 non-null  int64
#  1   Reviews  50919 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 795.7+ KB

# %% [markdown]
# ### Dataset is ready

# %% [markdown]
# ### Natural Language Processing(NLP) of the text(Reviews) data using nltk library

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
pst = PorterStemmer()
from nltk.probability import FreqDist
fdist = FreqDist()
import re

# %% [markdown]
# ### Importing Stopwords into a list and removing 'not' from the list

# %%
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')

# %% [markdown]
# ### Single function for text preprocessing - tokenization, removing punctuation marks, turning into lower case, stemming, removing stopwords

# %%
def text_preprocessing(reviews):
    all_tokens = []
    for i in range(0,len(reviews)):
        tokens = word_tokenize(reviews[i])
        all_tokens.append(tokens)
    final_corpus = []
    for i in all_tokens:
        temp_list = []
        temp_list2 = []
        for word in i:
            post_punctuation = re.sub('[^a-zA-Z]',' ',word)
            if len(post_punctuation) > 0:
                temp_list.append(post_punctuation)
        for word in temp_list:
            new_word = word.lower()
            temp_list2.append(new_word)
        post_stem = [pst.stem(word) for word in temp_list2 if not word in set(all_stopwords)]
        post_stem = ' '.join(post_stem)
        final_corpus.append(post_stem)
    return final_corpus,all_tokens

# %% [markdown]
# ### post_punctuation = re.sub('[^a-zA-Z]',' ',word) - error corrected, space must be there in ' '

# %% [markdown]
# ### calling function for text preprocessing

# %%
corpus,tokens = text_preprocessing(Amazon_data_final.Reviews)

# %%
len(corpus)
# Out:
# 50919

# %% [markdown]
# ### Sample of final processed text data

# %%
print(corpus[0:100])
# Out:
# [' s great money take time get synchron work good', 'worst     screw loos   water enter damag unit charger port     attent seller lousi          thing interest sell          ', 'item allot fun   n t go get rid smart phone   like mostli second phone play    s nice not practic  ', 'buy phone gift famili give problem   agenc author samsung took said phone not origin samsung brand   sad disillus amazon cellular provid not indic side phone not origin samsung price pay   attach imag team back not logo samsung materi thin plastic   also case cell phone back not complet inform specif box  ', 'got phone perfect condit   went go activ   turn previou owner outstand balanc sprint could not use   disappoint  ', 'pretti great phone   save money get one instead price newest version   iphon instead android phone way go   let compar iphon   smaller no finger print scanner no payment nfcdo realli need three featur   buy iphon     answer   save cash get one  ', 'phone power   shut not turn back   time come   got    white screen death    manual restart   incred frustrat irrit  ', 'not work   cant turn even charg   hour   mayb batteri not work    ', 'caution   phone not support samsung usa   not mention product page w found phone not support samsung us   call samsung custom servic phone not work wifi properli   connect slow wifi   googl see samsung devic issu   never get samsung support usa issu  ', 'perfect  ', 'phone order      deliv        work great first two day start mese screen jump take pictur screen goe red green   went request return find return window expir      day deliv   tri contact seller not anyon return call    disappoint  ', 'good product better expect  but need sim card lot featur not micro sim big sim', 'like watch     would recommend friend famili   best watch phone ever seen  ', 'work okay   freez sometim though sometim audio song app still go even get app   everyth fine', 'even complet set    new    phone screen froze   disappoint look forward blue dash   everyth els seem quit ok fear keep phone futur problem aris  ', 'phone excel   still tri find use featur n t tri look anyth onlin yet   call qualiti good   menu easili navig button easi use   built in flashlight life sav time   took box batteri regist     life n t charg one week   use flashlight repeatedli   talk sever hour differ day   first charg   least    day similar use charg again onli con would assign memori storag   ca n t input much calendar info need   also   figur assign one phone number per contact   display also hard read sun   time display small almost imposs read full daylight oth item   realli love phone   hope last long last one   blackberri pearl      seri last   year brutal abus    ', 'good choic', 'iphon   plu receiv less excel       look preform like new one appl   glass case like new phone wipe clean readi back up old phone   simpl clean   save big         price new appl    m happi     ', 'far good it purchas daughter use metro pc phone fine  ', 'bought phone august wife   phone hassl get go   two week purchas volum button start move errat   phone start hang not reset switch phone   need hold power button decreas volum button time   frequenc hang kept increas   even factori reset phone continu deterior   highli disappoint   would return phone window not elaps   not buy seller  ', 'spend extra buck get pebbl  ', 'iphon look new   work countryit not come complet accessori origin boxcharg adapt us standard not europ   buy europ standard charger adapt', 'phone look nice pretti   actual piec junk   work sever day      day   sudden decid not    make sound          ring tone   ca n t hear talk phone mean ca n t use    phone          wors   tri contact seller request explan refund sinc still within month n t even bother write back    s cheap pnone               one amazon  s loyal custom   think deserv least explan      ', 'super recommend go holiday usa need make purchas argentina   cell arriv earlier plan seller answer question quickli   hand   version cell  ...

# %% [markdown]
# ### finding top most frequent words in corpus with FreqDist() function

# %%
for word in corpus:
    fdist[word] += 1
top_10_words_corpus = fdist.most_common(10)
print(top_10_words_corpus)
# Out:
# [('good', 126), ('excel', 70), ('excelent', 49), ('ok', 43), ('excel  ', 35), ('love', 31), ('great', 28), ('love phone', 27), ('great product', 27), ('exel', 26)]

# %% [markdown]
# ### sample of tokens after tokenization

# %%
print(tokens[0:2])
# Out:
# [['It', "'s", 'great', 'for', 'the', 'money', 'just', 'takes', 'time', 'to', 'get', 'it', 'synchronize', 'works', 'good'], ['The', 'worst', '...', 'SCREW', 'LOOSE', ',', 'Water', 'entered', 'DAMAGE', 'THE', 'UNIT', 'AND', 'CHARGER', 'PORT', '...', 'THE', 'ATTENTION', 'OF', 'SELLER', 'IS', 'LOUSY', '...', '....', 'THE', 'ONLY', 'THING', 'THAT', 'IS', 'INTERESTED', 'IN', 'SELLING', 'THEM', '.......', '.']]

# %% [markdown]
# ### finding top most frequent words in tokens with FreqDist() function

# %%
for i in tokens:
    for word in i:
        fdist[word] += 1
top_10_words_tokens = fdist.most_common(40)
print(top_10_words_tokens)
# Out:
# [('.', 231471), ('the', 203870), (',', 166365), ('I', 154067), ('and', 124431), ('to', 117461), ('a', 112996), ('it', 108746), ('phone', 103260), ('is', 88445), ('this', 55221), ('for', 53776), ('of', 53214), ('with', 46471), ('that', 46093), ('not', 45103), ('was', 43476), ('in', 41969), ('on', 40490), ('my', 40049), ('!', 36145), ('you', 34918), ('but', 34891), ("n't", 34111), ('have', 33542), ('The', 29087), ('as', 24098), (')', 22793), ("'s", 22635), ('(', 21276), ('be', 20547), ('It', 19785), ('so', 19173), ('had', 17786), ('are', 17051), ('from', 17050), ('or', 17024), ('me', 17013), ('do', 16380), ('screen', 16374)]

# %% [markdown]
# ### printing wordcloud for final_corpus words - mpl.rcParams is about the figure size to display our wordcloud

# %%
import matplotlib as mpl
from wordcloud import WordCloud
mpl.rcParams['figure.figsize'] = 40,12

# %% [markdown]
# ### we need to collect the content of final_corpus as list of words in variable list_of_words

# %%
list_of_words = ''
for i in corpus:
    for word in i:
        list_of_words +=' '.join(word)
all_words = WordCloud(width=1000,height=500,background_color='black',min_font_size=10).generate(list_of_words)
plt.imshow(all_words)

# %% [markdown]
# ### Feature Extraction process from text data - Importing TFIDF Vectorizer from sklearn libray

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
feature_reviews = tfidf.fit_transform(corpus)

# %% [markdown]
# ### Deciding independent(X - feature vector from text data) and dependent(y - Ratings) variables

# %%
X = feature_reviews
y = Amazon_data_final.Rating

# %%
X.shape
# Out:
# (50919, 23260)

# %%
y.shape
# Out:
# (50919,)

# %% [markdown]
# ### Train test split in the ratio of 75:25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
X_train.shape
# Out:
# (38189, 23260)

# %%
X_test.shape
# Out:
# (12730, 23260)

# %%
from sklearn.svm import SVC
classifier = SVC()

# %%
classifier.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predict = classifier.predict(X_test)

# %% [markdown]
# ### Process of Evaluation - Importing Evaluation metrics

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,roc_curve
from sklearn.metrics import plot_confusion_matrix,classification_report

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[5620,   19,  113],
#        [ 272,  789,  183],
#        [ 172,   18, 5544]], dtype=int64)

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      5752
#            1       0.96      0.63      0.76      1244
#            2       0.95      0.97      0.96      5734
#
#     accuracy                           0.94     12730
#    macro avg       0.94      0.86      0.89     12730
# weighted avg       0.94      0.94      0.94     12730

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.9389630793401414

# %%
precision_score(y_test,y_predict,average='weighted')
# Out:
# 0.9397087948917673

# %%
recall_score(y_test,y_predict,average='weighted')
# Out:
# 0.9389630793401414

# %%
f1_score(y_test,y_predict,average='weighted')
# Out:
# 0.935833051614397
